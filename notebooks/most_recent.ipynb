# %%
import sqlite3
from pathlib import Path
from datetime import datetime, timedelta, timezone


def get_most_recent_episodes(db_path: Path, limit: int = 100):
    conn = sqlite3.connect(db_path)
    conn.row_factory = sqlite3.Row
    cursor = conn.cursor()

    query = """
        SELECT show_title, release_date FROM episode
        WHERE release_date IS NOT NULL
          AND datetime(release_date) <= datetime('now')
        ORDER BY release_date DESC
        LIMIT ?;
    """
    cursor.execute(query, (limit,))
    episodes = cursor.fetchall()
    conn.close()

    now = datetime.now(timezone.utc)  # make it timezone-aware

    for ep in episodes:
        try:
            release_dt = datetime.fromisoformat(ep["release_date"])
            if release_dt.tzinfo is None:
                release_dt = release_dt.replace(tzinfo=timezone.utc)

            delta = now - release_dt
            if delta < timedelta(minutes=1):
                readable = "just now"
            elif delta < timedelta(hours=1):
                readable = f"{int(delta.total_seconds() // 60)} mins ago"
            elif delta < timedelta(hours=24):
                readable = f"{int(delta.total_seconds() // 3600)} hrs ago"
            else:
                readable = release_dt.strftime("%Y-%m-%d")
        except ValueError:
            readable = ep["release_date"]  # fallback if parsing fails

        print(f"{ep['show_title']} — {readable}")


if __name__ == "__main__":
    get_most_recent_episodes(Path("../data/podcasts.db"))
# Out:
# Bedtime Stories for Kids|Good Night Tales|Whispers of May Night — 3 hrs ago
# Crime Stories with Nancy Grace — 4 hrs ago
# Central Station - True Stories from Outback Australia — 4 hrs ago
# Talking League - NRL Fantasy Podcast — 4 hrs ago
# Keeping It Real with Jac and Ral — 4 hrs ago
# The Jordan Syatt Podcast — 4 hrs ago
# Well There‘s Your Problem — 4 hrs ago
# The Reel Rejects — 4 hrs ago
# Wall Street Breakfast — 4 hrs ago
# The Reel Rejects — 4 hrs ago
# Golden Era Podcast with Sean Mooney — 4 hrs ago
# 无聊斋 — 4 hrs ago
# Missing Persons Mysteries — 4 hrs ago
# 异地登录 — 4 hrs ago
# Sous-sol et dragons — 4 hrs ago
# I am. with Kylie Lately — 4 hrs ago
# The Balance Theory — 4 hrs ago
# Les Grosses Têtes — 4 hrs ago
# Real America’s Voice — 4 hrs ago
# 1001 Classic Short Stories & Tales — 4 hrs ago
# 1001 Sherlock Holmes Stories & The Best of Sir Arthur Conan Doyle — 4 hrs ago
# Dad’s Bedtime Stories For Kids — 4 hrs ago
# Working Hard with Grace Beverley — 4 hrs ago
# Ludology — 4 hrs ago
# The Cult of Pedagogy Podcast — 4 hrs ago
# Mark Tilbury — 4 hrs ago
# The MeidasTouch Podcast — 4 hrs ago
# How I Met Your Podcast: A How I Met Your Mother Recap — 4 hrs ago
# The Herd with Colin Cowherd — 4 hrs ago
# Hugo Girard - Sans Limite — 5 hrs ago
# On refait le Mac - ORLM — 5 hrs ago
# Take Four Books — 5 hrs ago
# Bliss-Stories - Maternité sans filtre — 5 hrs ago
# Two Flogs — 5 hrs ago
# Partizán — 5 hrs ago
# Culips Everyday English Podcast — 5 hrs ago
# Winnipeg Sports Talk — 5 hrs ago
# Mark Tilbury — 5 hrs ago
# Crime Glacé — 5 hrs ago
# Saturday Night Network | SNL (Saturday Night Live) — 5 hrs ago
# Professor of Rock — 5 hrs ago
# In Defense of Plants Podcast — 5 hrs ago
# CCF Sermon Audio — 5 hrs ago
# The Flank — 5 hrs ago
# 매일성경_성서유니온 — 5 hrs ago
# 매일성경_성서유니온 — 5 hrs ago
# 매일성경_성서유니온 — 5 hrs ago
# Better Than Yesterday with Osher Günsberg — 5 hrs ago
# 歌聲後的故事 — 5 hrs ago
# 7 Good Minutes — 5 hrs ago
# Missing Persons Mysteries — 5 hrs ago
# Cryptid Creatures — 5 hrs ago
# Bartosz Czekała i podcast "The Universe of Memory" — 5 hrs ago
# The Martin Garrix Show — 5 hrs ago
# Ask Haviv Anything — 5 hrs ago
# The Days of Noah — 5 hrs ago
# The Connect- with Johnny Mitchell — 5 hrs ago
# The Apple WatchCast Podcast - A podcast dedicated to the Apple Watch — 5 hrs ago
# The Prancing Pony Podcast — 5 hrs ago
# 리딩 케미스트리 — 5 hrs ago
# A Chapter a Day Bible Reading — 5 hrs ago
# Sunburnt Souls — 5 hrs ago
# The Catholic Rosary — 5 hrs ago
# The Dog People Podcast — 5 hrs ago
# The Paul Taylor Podcast — 5 hrs ago
# Try Before You Die — 5 hrs ago
# Real America’s Voice — 5 hrs ago
# The Knicks Recap: A New York Knicks Podcast — 5 hrs ago
# Face à l'histoire — 5 hrs ago
# Historia en Podcast — 5 hrs ago
# Two Sides of FI — 5 hrs ago
# The Human Risk Podcast — 5 hrs ago
# The John Batchelor Show — 6 hrs ago
# L'art du mentaliste — 6 hrs ago
# Jack Hopkins — 6 hrs ago
# Radio Maria England — 6 hrs ago
# Just Tap In with Emilio Ortiz — 6 hrs ago
# Neurosurgery Podcast — 6 hrs ago
# PodSchool — 6 hrs ago
# NBC Meet the Press — 6 hrs ago
# Newshour — 6 hrs ago
# Буде тобі наука — 6 hrs ago
# The Word for Today — 6 hrs ago
# Fox News Hourly Update — 6 hrs ago
# NHKラジオニュース — 6 hrs ago
# Proper True Yarn — 6 hrs ago
# Sober Awkward — 6 hrs ago
# Shameless — 6 hrs ago
# Bloody Brilliant Beers — 6 hrs ago
# Missing Persons Mysteries — 6 hrs ago
# Journey to Truth Podcast CLASSICS — 6 hrs ago
# The Diddy Diaries — 6 hrs ago
# The Last Thing I Saw — 6 hrs ago
# The Checkup with Doctor Mike — 6 hrs ago
# Girl Core — 6 hrs ago
# Do You F*cking Mind? — 6 hrs ago
# Slipmatt's World Of Rave — 6 hrs ago
# Sound Museum — 6 hrs ago
# Trunk Talk — 6 hrs ago
# Over n Out — 6 hrs ago
